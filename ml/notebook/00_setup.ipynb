# %%
 import xgboost; print(xgboost.__version__)
# Out:
# 3.0.4

# %%
import urllib.request, zipfile, os, pandas as pd

# %%
url = "https://archive.ics.uci.edu/static/public/320/student+performance.zip"
urllib.request.urlretrieve(url, "../data/student_performance.zip")
with zipfile.ZipFile("../data/student_performance.zip") as z:
    z.extractall("../data/")

# %%
df = pd.read_csv("../data/student-mat.csv", sep=";")
print("Shape:", df.shape)         # should be (395, 33)
print("Columns:", df.columns.tolist())
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("../data/student-mat.csv", sep=";")
#       2 print("Shape:", df.shape)         # should be (395, 33)
#       3 print("Columns:", df.columns.tolist())
#       4 df.head(3)
#
# ...

# %%
df = pd.read_csv("../data/student-mat.csv", sep=";")
print("Shape:", df.shape)         # should be (395, 33)
print("Columns:", df.columns.tolist())
df.head(3)
# Out:
# Shape: (395, 33)
# Columns: ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2  G3
# 0      4        3      4     1     1      3        6  5  6   6
# 1      5        3      3     1     1      3        4  5  5   6
# 2      4        3      2     2     3      3       10  7  8  10
#
# [3 rows x 33 columns]
